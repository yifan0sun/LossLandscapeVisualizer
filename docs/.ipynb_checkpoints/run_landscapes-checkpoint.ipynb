# %%
import numpy as np
import multiprocessing as mp
from itertools import product


from visualize_landscape import *


torch.set_num_threads(1)

# %%
def worker(args):
    dataset, width, depth, ab_range, epoch, gridsize = args
    arch = [width] * depth

    try:
        #print(f"Processing: epoch={epoch}, ab_range={ab_range}, width={width}, depth={depth}, dataset={dataset}")
        compute_loss_grid( arch, dataset, train=True, epoch=epoch, ab_range=ab_range, gridsize=gridsize  )

        #compute_and_save_zrange(
        #    arch=arch,
        #    dataset=dataset,
        #    train=True,
        #    ab_range=ab_range,
        #    gridsize=gridsize
        #)
        print(f"Done: {dataset}, width={width}, depth={depth}, ab_range={ab_range}, epoch={epoch}")

    except Exception as e:
        print(f"Failed: {dataset}, width={width}, depth={depth}, ab_range={ab_range}, epoch={epoch}. Reason: {e}")
        


num_epochs = 1001
datasets = ["two_blobs_separate", "two_blobs_overlap", "half_moons", "spirals", "four_corners"]
widths = [5]#,10,25,50,100]  
depths = [1,2,4,8,16]  
ab_ranges = [0.1, 1, 10,2,5,.2,.5]
epochs = list(range(0, num_epochs, 10))
gridsize = 100

# Prepare the argument list for all jobs
all_args = list(product( widths, depths,datasets, ab_ranges, epochs))


all_args = [ (dataset,  width, depth, ab_range, epoch, gridsize) for ( width, depth, dataset,ab_range, epoch) in all_args]


#for args in all_args:
#    worker(args)


# Launch the multiprocessing pool
with mp.Pool(processes=15) as pool:
    pool.map(worker, all_args)
# Out:
# Done: two_blobs_separate, width=5, depth=1, ab_range=0.1, epoch=0Done: half_moons, width=5, depth=1, ab_range=0.1, epoch=590Done: four_corners, width=5, depth=1, ab_range=1, epoch=170
#
# Done: two_blobs_separate, width=5, depth=4, ab_range=10, epoch=930Done: spirals, width=5, depth=2, ab_range=10, epoch=340Done: two_blobs_overlap, width=5, depth=2, ab_range=1, epoch=760
# Done: half_moons, width=5, depth=4, ab_range=2, epoch=510
# Done: two_blobs_separate, width=5, depth=1, ab_range=0.1, epoch=10Done: half_moons, width=5, depth=1, ab_range=0.1, epoch=600
# Done: two_blobs_overlap, width=5, depth=8, ab_range=5, epoch=680Done: four_corners, width=5, depth=4, ab_range=5, epoch=90
# Done: four_corners, width=5, depth=1, ab_range=1, epoch=180
# Done: two_blobs_separate, width=5, depth=4, ab_range=10, epoch=940Done: spirals, width=5, depth=2, ab_range=10, epoch=350
# Done: spirals, width=5, depth=8, ab_range=0.2, epoch=260
# Done: half_moons, width=5, depth=4, ab_range=2, epoch=520
#
#
#
#
# Done: two_blobs_separate, width=5, depth=1, ab_range=0.1, epoch=20Done: two_blobs_overlap, width=5, depth=2, ab_range=1, epoch=770
# Done: half_moons, width=5, depth=1, ab_range=0.1, epoch=610Done: two_blobs_separate, width=5, depth=4, ab_range=10, epoch=950Done: four_corners, width=5, depth=4, ab_range=5, epoch=100Done: two_blobs_separate, width=5, depth=16, ab_range=0.2, epoch=850Done: four_corners, width=5, depth=1, ab_range=1, epoch=190Done: half_moons, width=5, depth=16, ab_range=0.5, epoch=430
# Done: spirals, width=5, depth=2, ab_range=10, epoch=360Done: two_blobs_overlap, width=5, depth=8, ab_range=5, epoch=690
#
# Done: spirals, width=5, depth=8, ab_range=0.2, epoch=270
#
#
#
# Done: two_blobs_separate, width=5, depth=4, ab_range=10, epoch=960Done: two_blobs_separate, width=10, depth=1, ab_range=0.1, epoch=10
# Done: two_blobs_separate, width=5, depth=1, ab_range=0.1, epoch=30Done: two_blobs_overlap, width=5, depth=2, ab_range=1, epoch=780
# Done: four_corners, width=5, depth=4, ab_range=5, epoch=110Done: half_moons, width=5, depth=1, ab_range=0.1, epoch=620Done: four_corners, width=5, depth=1, ab_range=1, epoch=200
# Done: two_blobs_separate, width=5, depth=16, ab_range=0.2, epoch=860Done: spirals, width=5, depth=2, ab_range=10, epoch=370
#
#
#
#
# Done: half_moons, width=10, depth=1, ab_range=0.1, epoch=600Done: four_corners, width=10, depth=1, ab_range=1, epoch=180
#
#
# Done: two_blobs_separate, width=5, depth=4, ab_range=10, epoch=970
# Done: two_blobs_separate, width=10, depth=1, ab_range=0.1, epoch=20
# Done: two_blobs_overlap, width=5, depth=2, ab_range=1, epoch=790Done: two_blobs_separate, width=5, depth=1, ab_range=0.1, epoch=40Done: half_moons, width=5, depth=4, ab_range=2, epoch=530Done: half_moons, width=5, depth=16, ab_range=0.5, epoch=440
#
# Done: spirals, width=5, depth=8, ab_range=0.2, epoch=280Done: four_corners, width=5, depth=4, ab_range=5, epoch=120
# Done: two_blobs_separate, width=5, depth=16, ab_range=0.2, epoch=870Done: half_moons, width=5, depth=1, ab_range=0.1, epoch=630Done: spirals, width=5, depth=2, ab_range=10, epoch=380
#
#
#
# Done: two_blobs_separate, width=10, depth=1, ab_range=0.1, epoch=30Done: half_moons, width=10, depth=1, ab_range=0.1, epoch=610
#
#
# Done: two_blobs_separate, width=5, depth=1, ab_range=0.1, epoch=50
# Done: four_corners, width=10, depth=1, ab_range=1, epoch=190
# Done: four_corners, width=5, depth=4, ab_range=5, epoch=130
# Done: two_blobs_separate, width=5, depth=4, ab_range=10, epoch=980
# Done: spirals, width=5, depth=2, ab_range=10, epoch=390
# Done: two_blobs_overlap, width=5, depth=2, ab_range=1, epoch=800
# Done: spirals, width=5, depth=8, ab_range=0.2, epoch=290
#
# Done: half_moons, width=5, depth=4, ab_range=2, epoch=540Done: four_corners, width=10, depth=1, ab_range=1, epoch=200Done: two_blobs_overlap, width=5, depth=8, ab_range=5, epoch=700
#
# Done: four_corners, width=5, depth=1, ab_range=1, epoch=210
# Done: half_moons, width=10, depth=1, ab_range=0.1, epoch=620
# Done: two_blobs_separate, width=5, depth=4, ab_range=10, epoch=990Done: half_moons, width=5, depth=16, ab_range=0.5, epoch=450
#
# Done: two_blobs_separate, width=5, depth=1, ab_range=0.1, epoch=60Done: two_blobs_separate, width=5, depth=16, ab_range=0.2, epoch=880
# Done: four_corners, width=5, depth=4, ab_range=5, epoch=140Done: half_moons, width=5, depth=1, ab_range=0.1, epoch=640Done: spirals, width=5, depth=8, ab_range=0.2, epoch=300Done: spirals, width=5, depth=2, ab_range=10, epoch=400
# Done: two_blobs_overlap, width=5, depth=2, ab_range=1, epoch=810
# Done: half_moons, width=5, depth=4, ab_range=2, epoch=550
#
# Done: half_moons, width=10, depth=1, ab_range=0.1, epoch=630
#
#
#
#
# Done: two_blobs_separate, width=5, depth=4, ab_range=10, epoch=1000Done: four_corners, width=5, depth=1, ab_range=1, epoch=220
#
#
#
# Done: two_blobs_overlap, width=5, depth=8, ab_range=5, epoch=710
# Done: four_corners, width=10, depth=1, ab_range=1, epoch=210
# Done: spirals, width=5, depth=8, ab_range=0.2, epoch=310Done: two_blobs_separate, width=5, depth=1, ab_range=0.1, epoch=70Done: four_corners, width=5, depth=4, ab_range=5, epoch=150Done: two_blobs_separate, width=5, depth=16, ab_range=0.2, epoch=890Done: half_moons, width=5, depth=16, ab_range=0.5, epoch=460Done: half_moons, width=5, depth=1, ab_range=0.1, epoch=650Done: half_moons, width=5, depth=4, ab_range=2, epoch=560
#
# Done: spirals, width=5, depth=2, ab_range=10, epoch=410Done: two_blobs_separate, width=10, depth=1, ab_range=0.1, epoch=40Done: two_blobs_separate, width=5, depth=4, ab_range=2, epoch=0
#
#
#
#
#
#
#
#
# Done: spirals, width=5, depth=8, ab_range=0.2, epoch=320Done: two_blobs_overlap, width=5, depth=8, ab_range=5, epoch=720
# Done: two_blobs_separate, width=5, depth=1, ab_range=0.1, epoch=80Done: four_corners, width=5, depth=4, ab_range=5, epoch=160Done: half_moons, width=5, depth=1, ab_range=0.1, epoch=660Done: two_blobs_overlap, width=5, depth=2, ab_range=1, epoch=820Done: half_moons, width=10, depth=1, ab_range=0.1, epoch=640Done: four_corners, width=10, depth=1, ab_range=1, epoch=220Done: half_moons, width=5, depth=4, ab_range=2, epoch=570Done: two_blobs_separate, width=10, depth=1, ab_range=0.1, epoch=50
# Done: four_corners, width=5, depth=1, ab_range=1, epoch=230
#
# Done: two_blobs_separate, width=5, depth=16, ab_range=0.2, epoch=900
# Done: half_moons, width=5, depth=16, ab_range=0.5, epoch=470
#
# Done: spirals, width=5, depth=2, ab_range=10, epoch=420
#
#
# Done: two_blobs_overlap, width=5, depth=8, ab_range=5, epoch=730
#
# Done: spirals, width=5, depth=8, ab_range=0.2, epoch=330Done: two_blobs_separate, width=5, depth=4, ab_range=2, epoch=10
# Done: four_corners, width=5, depth=4, ab_range=5, epoch=170Done: half_moons, width=10, depth=1, ab_range=0.1, epoch=650Done: four_corners, width=10, depth=1, ab_range=1, epoch=230
# Done: two_blobs_separate, width=5, depth=1, ab_range=0.1, epoch=90Done: two_blobs_separate, width=10, depth=1, ab_range=0.1, epoch=60
#
# Done: half_moons, width=5, depth=4, ab_range=2, epoch=580Done: two_blobs_separate, width=5, depth=16, ab_range=0.2, epoch=910Done: half_moons, width=5, depth=16, ab_range=0.5, epoch=480
#
#
# Done: two_blobs_overlap, width=5, depth=2, ab_range=1, epoch=830
#
#
# Done: half_moons, width=5, depth=1, ab_range=0.1, epoch=670
# Done: two_blobs_overlap, width=5, depth=8, ab_range=5, epoch=740
# Done: spirals, width=5, depth=2, ab_range=10, epoch=430
# Done: four_corners, width=5, depth=4, ab_range=5, epoch=180
#
#
# Done: half_moons, width=5, depth=4, ab_range=2, epoch=590Done: two_blobs_separate, width=5, depth=4, ab_range=2, epoch=20
# Done: half_moons, width=5, depth=16, ab_range=0.5, epoch=490Done: four_corners, width=5, depth=1, ab_range=1, epoch=240
# Done: two_blobs_separate, width=10, depth=1, ab_range=0.1, epoch=70Done: two_blobs_separate, width=5, depth=1, ab_range=0.1, epoch=100Done: two_blobs_overlap, width=5, depth=2, ab_range=1, epoch=840
# Done: half_moons, width=10, depth=1, ab_range=0.1, epoch=660
#
# Done: four_corners, width=5, depth=4, ab_range=5, epoch=190Done: spirals, width=5, depth=2, ab_range=10, epoch=440
#
#
# Done: half_moons, width=5, depth=1, ab_range=0.1, epoch=680
#
#
# Done: two_blobs_separate, width=10, depth=1, ab_range=0.1, epoch=80Done: two_blobs_overlap, width=5, depth=8, ab_range=5, epoch=750Done: half_moons, width=5, depth=16, ab_range=0.5, epoch=500
# Done: spirals, width=5, depth=8, ab_range=0.2, epoch=340Done: two_blobs_separate, width=5, depth=4, ab_range=2, epoch=30
# Done: half_moons, width=10, depth=1, ab_range=0.1, epoch=670Done: half_moons, width=5, depth=4, ab_range=2, epoch=600Done: four_corners, width=5, depth=1, ab_range=1, epoch=250
# Done: spirals, width=5, depth=2, ab_range=10, epoch=450Done: two_blobs_separate, width=5, depth=1, ab_range=0.1, epoch=110
#
#
#
#
#
# Done: two_blobs_overlap, width=5, depth=2, ab_range=1, epoch=850
# Done: two_blobs_separate, width=10, depth=1, ab_range=0.1, epoch=90Done: half_moons, width=5, depth=4, ab_range=2, epoch=610Done: half_moons, width=10, depth=1, ab_range=0.1, epoch=680
#
# Done: four_corners, width=5, depth=1, ab_range=1, epoch=260Done: four_corners, width=5, depth=4, ab_range=5, epoch=200
#
# Done: two_blobs_separate, width=5, depth=4, ab_range=2, epoch=40Done: spirals, width=5, depth=2, ab_range=10, epoch=460Done: half_moons, width=5, depth=1, ab_range=0.1, epoch=690
#
#
# Done: four_corners, width=10, depth=1, ab_range=1, epoch=240Done: half_moons, width=5, depth=16, ab_range=0.5, epoch=510
# Done: spirals, width=5, depth=8, ab_range=0.2, epoch=350
# Done: two_blobs_separate, width=5, depth=1, ab_range=0.1, epoch=120
# Done: two_blobs_overlap, width=5, depth=8, ab_range=5, epoch=760
# Done: two_blobs_overlap, width=5, depth=2, ab_range=1, epoch=860
# Done: half_moons, width=5, depth=4, ab_range=2, epoch=620
#
# Done: half_moons, width=10, depth=1, ab_range=0.1, epoch=690
#
#
# Done: two_blobs_separate, width=10, depth=1, ab_range=0.1, epoch=100Done: four_corners, width=5, depth=4, ab_range=5, epoch=210
# Done: half_moons, width=5, depth=1, ab_range=0.1, epoch=700
# Done: half_moons, width=5, depth=16, ab_range=0.5, epoch=520Done: four_corners, width=5, depth=1, ab_range=1, epoch=270Done: two_blobs_separate, width=5, depth=4, ab_range=2, epoch=50
# Done: spirals, width=5, depth=2, ab_range=10, epoch=470Done: spirals, width=5, depth=8, ab_range=0.2, epoch=360Done: two_blobs_separate, width=5, depth=1, ab_range=0.1, epoch=130Done: four_corners, width=10, depth=1, ab_range=1, epoch=250
#
#
#
# Done: two_blobs_overlap, width=5, depth=8, ab_range=5, epoch=770Done: two_blobs_overlap, width=5, depth=2, ab_range=1, epoch=870
#
# Done: half_moons, width=10, depth=1, ab_range=0.1, epoch=700
# Done: four_corners, width=5, depth=4, ab_range=5, epoch=220
# Done: two_blobs_separate, width=5, depth=16, ab_range=0.2, epoch=920
#
# Done: half_moons, width=5, depth=1, ab_range=0.1, epoch=710Done: two_blobs_separate, width=10, depth=1, ab_range=0.1, epoch=110
#
# Done: half_moons, width=5, depth=16, ab_range=0.5, epoch=530
# Done: spirals, width=5, depth=8, ab_range=0.2, epoch=370
#
# Done: spirals, width=5, depth=2, ab_range=10, epoch=480Done: four_corners, width=10, depth=1, ab_range=1, epoch=260Done: two_blobs_overlap, width=5, depth=8, ab_range=5, epoch=780
# Done: two_blobs_separate, width=5, depth=4, ab_range=2, epoch=60Done: half_moons, width=5, depth=4, ab_range=2, epoch=630
# Done: four_corners, width=5, depth=1, ab_range=1, epoch=280Done: two_blobs_separate, width=5, depth=1, ab_range=0.1, epoch=140
# Done: half_moons, width=10, depth=1, ab_range=0.1, epoch=710Done: two_blobs_overlap, width=5, depth=2, ab_range=1, epoch=880
#
#
# Done: half_moons, width=5, depth=1, ab_range=0.1, epoch=720
#
# Done: four_corners, width=5, depth=4, ab_range=5, epoch=230
#
#
#
# Done: two_blobs_separate, width=5, depth=16, ab_range=0.2, epoch=930
#
# Done: two_blobs_overlap, width=5, depth=8, ab_range=5, epoch=790Done: spirals, width=5, depth=8, ab_range=0.2, epoch=380Done: spirals, width=5, depth=2, ab_range=10, epoch=490Done: four_corners, width=10, depth=1, ab_range=1, epoch=270
# Done: four_corners, width=5, depth=1, ab_range=1, epoch=290Done: half_moons, width=5, depth=4, ab_range=2, epoch=640Done: two_blobs_separate, width=5, depth=4, ab_range=2, epoch=70
#
#
# Done: two_blobs_overlap, width=5, depth=2, ab_range=1, epoch=890
# Done: half_moons, width=5, depth=1, ab_range=0.1, epoch=730Done: half_moons, width=10, depth=1, ab_range=0.1, epoch=720Done: two_blobs_separate, width=5, depth=1, ab_range=0.1, epoch=150
# Done: two_blobs_separate, width=10, depth=1, ab_range=0.1, epoch=120Done: two_blobs_separate, width=5, depth=16, ab_range=0.2, epoch=940
#
#
#
# Done: four_corners, width=5, depth=4, ab_range=5, epoch=240Done: spirals, width=5, depth=2, ab_range=10, epoch=500Done: spirals, width=5, depth=8, ab_range=0.2, epoch=390
# Done: four_corners, width=10, depth=1, ab_range=1, epoch=280
#
#
# Done: two_blobs_overlap, width=5, depth=8, ab_range=5, epoch=800Done: half_moons, width=5, depth=4, ab_range=2, epoch=650
# Done: four_corners, width=5, depth=1, ab_range=1, epoch=300
#
#
# Done: two_blobs_overlap, width=5, depth=2, ab_range=1, epoch=900Done: two_blobs_separate, width=10, depth=1, ab_range=0.1, epoch=130
# Done: two_blobs_separate, width=5, depth=4, ab_range=2, epoch=80
#
# Done: two_blobs_separate, width=5, depth=16, ab_range=0.2, epoch=950Done: two_blobs_separate, width=5, depth=1, ab_range=0.1, epoch=160
# Done: half_moons, width=10, depth=1, ab_range=0.1, epoch=730
#
#
#
# Done: half_moons, width=5, depth=16, ab_range=0.5, epoch=540Done: spirals, width=5, depth=2, ab_range=10, epoch=510Done: spirals, width=5, depth=8, ab_range=0.2, epoch=400Done: two_blobs_overlap, width=5, depth=8, ab_range=5, epoch=810Done: four_corners, width=10, depth=1, ab_range=1, epoch=290Done: four_corners, width=5, depth=4, ab_range=5, epoch=250
#
# Done: half_moons, width=5, depth=4, ab_range=2, epoch=660Done: four_corners, width=5, depth=1, ab_range=1, epoch=310Done: two_blobs_separate, width=10, depth=1, ab_range=0.1, epoch=140
# Done: two_blobs_overlap, width=5, depth=2, ab_range=1, epoch=910
#
#
#
#
# Done: two_blobs_separate, width=5, depth=1, ab_range=0.1, epoch=170Done: two_blobs_separate, width=5, depth=4, ab_range=2, epoch=90
# Done: two_blobs_separate, width=5, depth=16, ab_range=0.2, epoch=960
#
#
#
# Done: half_moons, width=10, depth=1, ab_range=0.1, epoch=740Done: half_moons, width=5, depth=16, ab_range=0.5, epoch=550
# Done: two_blobs_overlap, width=5, depth=8, ab_range=5, epoch=820Done: four_corners, width=10, depth=1, ab_range=1, epoch=300
# Done: two_blobs_separate, width=10, depth=1, ab_range=0.1, epoch=150Done: four_corners, width=5, depth=4, ab_range=5, epoch=260Done: spirals, width=5, depth=2, ab_range=10, epoch=520Done: spirals, width=5, depth=8, ab_range=0.2, epoch=410Done: half_moons, width=5, depth=4, ab_range=2, epoch=670
# Done: half_moons, width=5, depth=1, ab_range=0.1, epoch=740
# Done: two_blobs_overlap, width=5, depth=2, ab_range=1, epoch=920Done: four_corners, width=5, depth=1, ab_range=1, epoch=320
# Done: two_blobs_separate, width=5, depth=4, ab_range=2, epoch=100Done: two_blobs_separate, width=5, depth=1, ab_range=0.1, epoch=180
#
#
#
#
#
#
# Done: half_moons, width=10, depth=1, ab_range=0.1, epoch=750
#
# Done: two_blobs_overlap, width=5, depth=8, ab_range=5, epoch=830
# Done: spirals, width=5, depth=2, ab_range=10, epoch=530
# Done: half_moons, width=5, depth=16, ab_range=0.5, epoch=560Done: half_moons, width=5, depth=4, ab_range=2, epoch=680Done: two_blobs_separate, width=10, depth=1, ab_range=0.1, epoch=160Done: spirals, width=5, depth=8, ab_range=0.2, epoch=420Done: two_blobs_separate, width=5, depth=16, ab_range=0.2, epoch=970Done: four_corners, width=5, depth=4, ab_range=5, epoch=270Done: four_corners, width=10, depth=1, ab_range=1, epoch=310
# Done: four_corners, width=5, depth=1, ab_range=1, epoch=330Done: two_blobs_separate, width=5, depth=4, ab_range=2, epoch=110
#
# Done: two_blobs_overlap, width=5, depth=2, ab_range=1, epoch=930
#
#
#
#
#
# Done: half_moons, width=10, depth=1, ab_range=0.1, epoch=760Done: spirals, width=5, depth=2, ab_range=10, epoch=540
#
#
#
#
# Done: half_moons, width=5, depth=4, ab_range=2, epoch=690Done: half_moons, width=5, depth=1, ab_range=0.1, epoch=750Done: two_blobs_separate, width=5, depth=16, ab_range=0.2, epoch=980Done: spirals, width=5, depth=8, ab_range=0.2, epoch=430Done: four_corners, width=10, depth=1, ab_range=1, epoch=320
# Done: four_corners, width=5, depth=1, ab_range=1, epoch=340Done: two_blobs_separate, width=10, depth=1, ab_range=0.1, epoch=170Done: two_blobs_separate, width=5, depth=4, ab_range=2, epoch=120Done: two_blobs_overlap, width=5, depth=8, ab_range=5, epoch=840Done: two_blobs_overlap, width=5, depth=2, ab_range=1, epoch=940Done: two_blobs_separate, width=5, depth=1, ab_range=0.1, epoch=190
# Done: four_corners, width=5, depth=4, ab_range=5, epoch=280
#
#
#
#
#
# Done: half_moons, width=10, depth=1, ab_range=0.1, epoch=770
#
#
#
#
# Done: half_moons, width=5, depth=4, ab_range=2, epoch=700Done: two_blobs_separate, width=5, depth=16, ab_range=0.2, epoch=990Done: half_moons, width=5, depth=1, ab_range=0.1, epoch=760Done: two_blobs_separate, width=10, depth=1, ab_range=0.1, epoch=180
# Done: four_corners, width=10, depth=1, ab_range=1, epoch=330Done: four_corners, width=5, depth=1, ab_range=1, epoch=350Done: two_blobs_overlap, width=5, depth=2, ab_range=1, epoch=950Done: two_blobs_overlap, width=5, depth=8, ab_range=5, epoch=850Done: two_blobs_separate, width=5, depth=1, ab_range=0.1, epoch=200
# Done: four_corners, width=5, depth=4, ab_range=5, epoch=290Done: spirals, width=5, depth=8, ab_range=0.2, epoch=440
#
#
#
#
# Done: half_moons, width=10, depth=1, ab_range=0.1, epoch=780
#
#
# Done: half_moons, width=5, depth=4, ab_range=2, epoch=710
# Done: two_blobs_separate, width=10, depth=1, ab_range=0.1, epoch=190
# Done: two_blobs_separate, width=5, depth=16, ab_range=0.2, epoch=1000Done: half_moons, width=5, depth=1, ab_range=0.1, epoch=770Done: four_corners, width=5, depth=1, ab_range=1, epoch=360Done: four_corners, width=10, depth=1, ab_range=1, epoch=340Done: half_moons, width=5, depth=16, ab_range=0.5, epoch=570Done: two_blobs_overlap, width=5, depth=2, ab_range=1, epoch=960Done: two_blobs_separate, width=5, depth=1, ab_range=0.1, epoch=210
#
#
# Done: two_blobs_separate, width=5, depth=4, ab_range=2, epoch=130
# Done: two_blobs_overlap, width=5, depth=8, ab_range=5, epoch=860
# Done: spirals, width=5, depth=8, ab_range=0.2, epoch=450
# Done: four_corners, width=5, depth=4, ab_range=5, epoch=300
#
#
#
#
# Done: two_blobs_separate, width=10, depth=1, ab_range=0.1, epoch=200Done: half_moons, width=5, depth=4, ab_range=2, epoch=720
# Done: half_moons, width=10, depth=1, ab_range=0.1, epoch=790Done: four_corners, width=5, depth=1, ab_range=1, epoch=370
# Done: half_moons, width=5, depth=1, ab_range=0.1, epoch=780Done: spirals, width=5, depth=2, ab_range=10, epoch=550Done: four_corners, width=10, depth=1, ab_range=1, epoch=350Done: two_blobs_overlap, width=5, depth=2, ab_range=1, epoch=970Done: two_blobs_separate, width=5, depth=1, ab_range=0.1, epoch=220
# Done: half_moons, width=5, depth=16, ab_range=0.5, epoch=580
# Done: two_blobs_separate, width=5, depth=16, ab_range=0.5, epoch=0
#
#
#
# Done: two_blobs_overlap, width=5, depth=8, ab_range=5, epoch=870Done: two_blobs_separate, width=5, depth=4, ab_range=2, epoch=140
#
#
#
# Done: two_blobs_separate, width=10, depth=1, ab_range=0.1, epoch=210
# Done: half_moons, width=10, depth=1, ab_range=0.1, epoch=800
#
# Done: four_corners, width=5, depth=1, ab_range=1, epoch=380
# Done: spirals, width=5, depth=8, ab_range=0.2, epoch=460
# Done: half_moons, width=5, depth=4, ab_range=2, epoch=730Done: spirals, width=5, depth=2, ab_range=10, epoch=560Done: four_corners, width=5, depth=4, ab_range=5, epoch=310Done: four_corners, width=10, depth=1, ab_range=1, epoch=360Done: two_blobs_separate, width=5, depth=1, ab_range=0.1, epoch=230
#
# Done: two_blobs_overlap, width=5, depth=2, ab_range=1, epoch=980Done: half_moons, width=5, depth=1, ab_range=0.1, epoch=790Done: half_moons, width=5, depth=16, ab_range=0.5, epoch=590
#
# Done: two_blobs_overlap, width=5, depth=8, ab_range=5, epoch=880
# Done: two_blobs_separate, width=5, depth=16, ab_range=0.5, epoch=10Done: two_blobs_separate, width=5, depth=4, ab_range=2, epoch=150
#
#
# Done: two_blobs_separate, width=10, depth=1, ab_range=0.1, epoch=220
#
# Done: four_corners, width=5, depth=1, ab_range=1, epoch=390Done: half_moons, width=10, depth=1, ab_range=0.1, epoch=810
#
# Done: spirals, width=5, depth=8, ab_range=0.2, epoch=470
#
#
# Done: four_corners, width=10, depth=1, ab_range=1, epoch=370Done: half_moons, width=5, depth=1, ab_range=0.1, epoch=800
# Done: half_moons, width=5, depth=4, ab_range=2, epoch=740Done: two_blobs_separate, width=5, depth=1, ab_range=0.1, epoch=240Done: half_moons, width=5, depth=16, ab_range=0.5, epoch=600
#
# Done: four_corners, width=5, depth=4, ab_range=5, epoch=320Done: spirals, width=5, depth=2, ab_range=10, epoch=570Done: two_blobs_overlap, width=5, depth=2, ab_range=1, epoch=990
# Done: two_blobs_separate, width=10, depth=1, ab_range=0.1, epoch=230
#
#
# Done: two_blobs_separate, width=5, depth=16, ab_range=0.5, epoch=20Done: two_blobs_overlap, width=5, depth=8, ab_range=5, epoch=890Done: two_blobs_separate, width=5, depth=4, ab_range=2, epoch=160
# Done: four_corners, width=5, depth=1, ab_range=1, epoch=400Done: half_moons, width=10, depth=1, ab_range=0.1, epoch=820
#
#
# Done: half_moons, width=5, depth=4, ab_range=2, epoch=750
# Done: half_moons, width=5, depth=1, ab_range=0.1, epoch=810Done: four_corners, width=10, depth=1, ab_range=1, epoch=380
# Done: two_blobs_separate, width=5, depth=1, ab_range=0.1, epoch=250
#
# Done: half_moons, width=5, depth=16, ab_range=0.5, epoch=610
#
#
#
# Done: two_blobs_separate, width=10, depth=1, ab_range=0.1, epoch=240Done: four_corners, width=5, depth=4, ab_range=5, epoch=330Done: two_blobs_overlap, width=5, depth=8, ab_range=5, epoch=900
# Done: two_blobs_overlap, width=5, depth=2, ab_range=1, epoch=1000Done: two_blobs_separate, width=5, depth=16, ab_range=0.5, epoch=30Done: spirals, width=5, depth=2, ab_range=10, epoch=580
#
# Done: four_corners, width=5, depth=1, ab_range=1, epoch=410
# Done: half_moons, width=10, depth=1, ab_range=0.1, epoch=830
#
# Done: two_blobs_separate, width=5, depth=4, ab_range=2, epoch=170
# Done: spirals, width=5, depth=8, ab_range=0.2, epoch=480
# Done: half_moons, width=5, depth=4, ab_range=2, epoch=760
# Done: half_moons, width=5, depth=16, ab_range=0.5, epoch=620
# Done: half_moons, width=5, depth=1, ab_range=0.1, epoch=820Done: two_blobs_separate, width=5, depth=1, ab_range=0.1, epoch=260
# Done: two_blobs_separate, width=10, depth=1, ab_range=0.1, epoch=250Done: four_corners, width=10, depth=1, ab_range=1, epoch=390
#
#
# Done: two_blobs_overlap, width=5, depth=8, ab_range=5, epoch=910Done: two_blobs_overlap, width=5, depth=2, ab_range=10, epoch=0
# Done: two_blobs_separate, width=5, depth=16, ab_range=0.5, epoch=40
#
#
#
#
# Done: four_corners, width=5, depth=1, ab_range=1, epoch=420
#
# Done: spirals, width=5, depth=2, ab_range=10, epoch=590
# Done: spirals, width=5, depth=8, ab_range=0.2, epoch=490Done: half_moons, width=10, depth=1, ab_range=0.1, epoch=840Done: two_blobs_separate, width=5, depth=4, ab_range=2, epoch=180Done: two_blobs_separate, width=5, depth=1, ab_range=0.1, epoch=270Done: half_moons, width=5, depth=16, ab_range=0.5, epoch=630Done: half_moons, width=5, depth=4, ab_range=2, epoch=770
# Done: two_blobs_overlap, width=5, depth=8, ab_range=5, epoch=920Done: four_corners, width=10, depth=1, ab_range=1, epoch=400
#
#
# Done: two_blobs_overlap, width=5, depth=2, ab_range=10, epoch=10
#
# Done: two_blobs_separate, width=5, depth=16, ab_range=0.5, epoch=50
#
#
#
# Done: half_moons, width=5, depth=1, ab_range=0.1, epoch=830Done: two_blobs_separate, width=10, depth=1, ab_range=0.1, epoch=260
# Done: two_blobs_separate, width=5, depth=1, ab_range=0.1, epoch=280Done: four_corners, width=5, depth=1, ab_range=1, epoch=430Done: half_moons, width=10, depth=1, ab_range=0.1, epoch=850Done: spirals, width=5, depth=2, ab_range=10, epoch=600
# Done: spirals, width=5, depth=8, ab_range=0.2, epoch=500Done: half_moons, width=5, depth=16, ab_range=0.5, epoch=640Done: two_blobs_overlap, width=5, depth=8, ab_range=5, epoch=930Done: two_blobs_separate, width=5, depth=4, ab_range=2, epoch=190Done: four_corners, width=10, depth=1, ab_range=1, epoch=410
#
#
# Done: two_blobs_overlap, width=5, depth=2, ab_range=10, epoch=20
#
#
# Done: two_blobs_separate, width=5, depth=16, ab_range=0.5, epoch=60
# Done: four_corners, width=5, depth=4, ab_range=5, epoch=340
#
#
#
# Done: half_moons, width=5, depth=1, ab_range=0.1, epoch=840
# Done: two_blobs_separate, width=5, depth=1, ab_range=0.1, epoch=290Done: two_blobs_separate, width=10, depth=1, ab_range=0.1, epoch=270
# Done: spirals, width=5, depth=2, ab_range=10, epoch=610
# Done: two_blobs_overlap, width=5, depth=8, ab_range=5, epoch=940Done: half_moons, width=10, depth=1, ab_range=0.1, epoch=860Done: half_moons, width=5, depth=4, ab_range=2, epoch=780Done: four_corners, width=5, depth=1, ab_range=1, epoch=440Done: spirals, width=5, depth=8, ab_range=0.2, epoch=510Done: half_moons, width=5, depth=16, ab_range=0.5, epoch=650Done: two_blobs_overlap, width=5, depth=2, ab_range=10, epoch=30Done: two_blobs_separate, width=5, depth=4, ab_range=2, epoch=200Done: four_corners, width=10, depth=1, ab_range=1, epoch=420
#
#
#
#
# Done: two_blobs_separate, width=5, depth=16, ab_range=0.5, epoch=70Done: four_corners, width=5, depth=4, ab_range=5, epoch=350
#
#
#
#
#
# Done: two_blobs_separate, width=10, depth=1, ab_range=0.1, epoch=280Done: two_blobs_separate, width=5, depth=1, ab_range=0.1, epoch=300Done: two_blobs_overlap, width=5, depth=8, ab_range=5, epoch=950
# Done: half_moons, width=5, depth=1, ab_range=0.1, epoch=850
# Done: spirals, width=5, depth=2, ab_range=10, epoch=620Done: half_moons, width=10, depth=1, ab_range=0.1, epoch=870Done: spirals, width=5, depth=8, ab_range=0.2, epoch=520
#
# Done: half_moons, width=5, depth=4, ab_range=2, epoch=790Done: half_moons, width=5, depth=16, ab_range=0.5, epoch=660Done: two_blobs_overlap, width=5, depth=2, ab_range=10, epoch=40Done: four_corners, width=10, depth=1, ab_range=1, epoch=430Done: two_blobs_separate, width=5, depth=4, ab_range=2, epoch=210
#
#
# Done: four_corners, width=5, depth=4, ab_range=5, epoch=360
#
#
#
# Done: two_blobs_separate, width=10, depth=1, ab_range=0.1, epoch=290
#
# Done: two_blobs_separate, width=5, depth=16, ab_range=0.5, epoch=80Done: two_blobs_overlap, width=5, depth=8, ab_range=5, epoch=960Done: two_blobs_separate, width=5, depth=1, ab_range=0.1, epoch=310
#
# Done: spirals, width=5, depth=8, ab_range=0.2, epoch=530Done: half_moons, width=5, depth=1, ab_range=0.1, epoch=860Done: half_moons, width=10, depth=1, ab_range=0.1, epoch=880
#
# Done: half_moons, width=5, depth=16, ab_range=0.5, epoch=670
# Done: spirals, width=5, depth=2, ab_range=10, epoch=630Done: half_moons, width=5, depth=4, ab_range=2, epoch=800Done: four_corners, width=10, depth=1, ab_range=1, epoch=440
#
# Done: two_blobs_separate, width=5, depth=4, ab_range=2, epoch=220Done: four_corners, width=5, depth=4, ab_range=5, epoch=370
#
#
#
# Done: two_blobs_separate, width=10, depth=1, ab_range=0.1, epoch=300
# Done: four_corners, width=5, depth=1, ab_range=1, epoch=450
#
# Done: two_blobs_separate, width=5, depth=1, ab_range=0.1, epoch=320
# Done: two_blobs_separate, width=5, depth=16, ab_range=0.5, epoch=90Done: half_moons, width=5, depth=1, ab_range=0.1, epoch=870Done: two_blobs_overlap, width=5, depth=8, ab_range=5, epoch=970Done: spirals, width=5, depth=8, ab_range=0.2, epoch=540Done: two_blobs_overlap, width=5, depth=2, ab_range=10, epoch=50
# Done: half_moons, width=10, depth=1, ab_range=0.1, epoch=890
#
# Done: spirals, width=5, depth=2, ab_range=10, epoch=640
#
# Done: four_corners, width=10, depth=1, ab_range=1, epoch=450Done: half_moons, width=5, depth=16, ab_range=0.5, epoch=680
#
# Done: half_moons, width=5, depth=4, ab_range=2, epoch=810
#
# Done: four_corners, width=5, depth=4, ab_range=5, epoch=380Done: two_blobs_separate, width=5, depth=1, ab_range=0.1, epoch=330Done: four_corners, width=5, depth=1, ab_range=1, epoch=460
# Done: two_blobs_separate, width=5, depth=4, ab_range=2, epoch=230
#
#
# Done: two_blobs_separate, width=5, depth=16, ab_range=0.5, epoch=100Done: two_blobs_separate, width=10, depth=1, ab_range=0.1, epoch=310Done: half_moons, width=5, depth=1, ab_range=0.1, epoch=880
# Done: two_blobs_overlap, width=5, depth=8, ab_range=5, epoch=980
# Done: half_moons, width=10, depth=1, ab_range=0.1, epoch=900
# Done: two_blobs_overlap, width=5, depth=2, ab_range=10, epoch=60
#
#
# Done: spirals, width=5, depth=2, ab_range=10, epoch=650Done: half_moons, width=5, depth=16, ab_range=0.5, epoch=690
#
# Done: two_blobs_separate, width=5, depth=1, ab_range=0.1, epoch=340
#
#
# Done: half_moons, width=5, depth=4, ab_range=2, epoch=820Done: four_corners, width=5, depth=4, ab_range=5, epoch=390Done: four_corners, width=5, depth=1, ab_range=1, epoch=470Done: two_blobs_separate, width=5, depth=4, ab_range=2, epoch=240
#
# Done: two_blobs_separate, width=5, depth=16, ab_range=0.5, epoch=110Done: two_blobs_separate, width=10, depth=1, ab_range=0.1, epoch=320
#
# Done: two_blobs_overlap, width=5, depth=8, ab_range=5, epoch=990Done: four_corners, width=10, depth=1, ab_range=1, epoch=460Done: half_moons, width=10, depth=1, ab_range=0.1, epoch=910Done: half_moons, width=5, depth=1, ab_range=0.1, epoch=890
#
#
#
#
# Done: half_moons, width=5, depth=16, ab_range=0.5, epoch=700Done: spirals, width=5, depth=2, ab_range=10, epoch=660Done: two_blobs_separate, width=5, depth=1, ab_range=0.1, epoch=350
#
# Done: spirals, width=5, depth=8, ab_range=0.2, epoch=550
# Done: two_blobs_separate, width=5, depth=4, ab_range=2, epoch=250
#
# Done: four_corners, width=5, depth=1, ab_range=1, epoch=480Done: half_moons, width=5, depth=4, ab_range=2, epoch=830Done: four_corners, width=5, depth=4, ab_range=5, epoch=400
# Done: two_blobs_separate, width=5, depth=16, ab_range=0.5, epoch=120
#
#
#
# Done: two_blobs_separate, width=10, depth=1, ab_range=0.1, epoch=330Done: half_moons, width=10, depth=1, ab_range=0.1, epoch=920
# Done: two_blobs_overlap, width=5, depth=8, ab_range=5, epoch=1000Done: two_blobs_overlap, width=5, depth=2, ab_range=10, epoch=70Done: four_corners, width=10, depth=1, ab_range=1, epoch=470Done: half_moons, width=5, depth=1, ab_range=0.1, epoch=900
# Done: spirals, width=5, depth=2, ab_range=10, epoch=670
# Done: half_moons, width=5, depth=16, ab_range=0.5, epoch=710Done: spirals, width=5, depth=8, ab_range=0.2, epoch=560
# Done: two_blobs_separate, width=5, depth=1, ab_range=0.1, epoch=360
# Done: two_blobs_separate, width=5, depth=4, ab_range=2, epoch=260
#
#
#
# Done: four_corners, width=5, depth=1, ab_range=1, epoch=490
#
#
# Done: half_moons, width=5, depth=4, ab_range=2, epoch=840
# Done: two_blobs_separate, width=10, depth=1, ab_range=0.1, epoch=340Done: two_blobs_separate, width=5, depth=16, ab_range=0.5, epoch=130
# Done: four_corners, width=10, depth=1, ab_range=1, epoch=480
# Done: two_blobs_overlap, width=5, depth=2, ab_range=10, epoch=80Done: half_moons, width=5, depth=1, ab_range=0.1, epoch=910Done: half_moons, width=10, depth=1, ab_range=0.1, epoch=930Done: two_blobs_overlap, width=5, depth=8, ab_range=0.2, epoch=0
# Done: spirals, width=5, depth=2, ab_range=10, epoch=680
# Done: four_corners, width=5, depth=1, ab_range=1, epoch=500
# Done: spirals, width=5, depth=8, ab_range=0.2, epoch=570Done: two_blobs_separate, width=5, depth=1, ab_range=0.1, epoch=370
# Done: two_blobs_separate, width=5, depth=4, ab_range=2, epoch=270
#
#
#
# Done: four_corners, width=10, depth=1, ab_range=1, epoch=490
# Done: two_blobs_separate, width=5, depth=16, ab_range=0.5, epoch=140Done: four_corners, width=5, depth=4, ab_range=5, epoch=410
# Done: two_blobs_separate, width=10, depth=1, ab_range=0.1, epoch=350
#
# Done: half_moons, width=5, depth=1, ab_range=0.1, epoch=920
# Done: half_moons, width=10, depth=1, ab_range=0.1, epoch=940
#
# Done: two_blobs_overlap, width=5, depth=8, ab_range=0.2, epoch=10Done: two_blobs_overlap, width=5, depth=2, ab_range=10, epoch=90Done: four_corners, width=5, depth=1, ab_range=1, epoch=510
#
# Done: two_blobs_separate, width=5, depth=4, ab_range=2, epoch=280Done: two_blobs_separate, width=5, depth=1, ab_range=0.1, epoch=380
# Done: spirals, width=5, depth=8, ab_range=0.2, epoch=580Done: half_moons, width=5, depth=4, ab_range=2, epoch=850
# Done: spirals, width=5, depth=2, ab_range=10, epoch=690Done: half_moons, width=5, depth=16, ab_range=0.5, epoch=720
#
# Done: four_corners, width=10, depth=1, ab_range=1, epoch=500Done: two_blobs_separate, width=10, depth=1, ab_range=0.1, epoch=360
#
#
#
# Done: half_moons, width=10, depth=1, ab_range=0.1, epoch=950Done: half_moons, width=5, depth=1, ab_range=0.1, epoch=930Done: four_corners, width=5, depth=4, ab_range=5, epoch=420
#
#
#
#
#
# Done: two_blobs_separate, width=5, depth=1, ab_range=0.1, epoch=390Done: four_corners, width=5, depth=1, ab_range=1, epoch=520Done: two_blobs_overlap, width=5, depth=2, ab_range=10, epoch=100
#
# Done: two_blobs_overlap, width=5, depth=8, ab_range=0.2, epoch=20Done: half_moons, width=5, depth=4, ab_range=2, epoch=860Done: two_blobs_separate, width=5, depth=4, ab_range=2, epoch=290Done: two_blobs_separate, width=5, depth=16, ab_range=0.5, epoch=150Done: two_blobs_separate, width=10, depth=1, ab_range=0.1, epoch=370Done: spirals, width=5, depth=2, ab_range=10, epoch=700Done: four_corners, width=10, depth=1, ab_range=1, epoch=510
# Done: half_moons, width=5, depth=16, ab_range=0.5, epoch=730
#
#
# Done: half_moons, width=10, depth=1, ab_range=0.1, epoch=960
# Done: four_corners, width=5, depth=4, ab_range=5, epoch=430
#
#
# Done: spirals, width=5, depth=8, ab_range=0.2, epoch=590
# Done: four_corners, width=5, depth=1, ab_range=1, epoch=530Done: two_blobs_overlap, width=5, depth=2, ab_range=10, epoch=110Done: two_blobs_separate, width=5, depth=1, ab_range=0.1, epoch=400
#
# Done: two_blobs_overlap, width=5, depth=8, ab_range=0.2, epoch=30
#
# Done: half_moons, width=5, depth=4, ab_range=2, epoch=870
#
# Done: two_blobs_separate, width=5, depth=16, ab_range=0.5, epoch=160Done: two_blobs_separate, width=10, depth=1, ab_range=0.1, epoch=380Done: two_blobs_separate, width=5, depth=4, ab_range=2, epoch=300
#
#
# Done: spirals, width=5, depth=2, ab_range=10, epoch=710Done: four_corners, width=10, depth=1, ab_range=1, epoch=520Done: half_moons, width=10, depth=1, ab_range=0.1, epoch=970Done: four_corners, width=5, depth=4, ab_range=5, epoch=440
#
# Done: spirals, width=5, depth=8, ab_range=0.2, epoch=600
#
# Done: half_moons, width=5, depth=1, ab_range=0.1, epoch=940Done: four_corners, width=5, depth=1, ab_range=1, epoch=540
#
# Done: two_blobs_overlap, width=5, depth=2, ab_range=10, epoch=120
# Done: two_blobs_overlap, width=5, depth=8, ab_range=0.2, epoch=40
#
# Done: two_blobs_separate, width=5, depth=1, ab_range=0.1, epoch=410Done: two_blobs_separate, width=10, depth=1, ab_range=0.1, epoch=390
# Done: two_blobs_separate, width=5, depth=16, ab_range=0.5, epoch=170
#
#
# Done: half_moons, width=10, depth=1, ab_range=0.1, epoch=980Done: four_corners, width=5, depth=4, ab_range=5, epoch=450Done: half_moons, width=5, depth=4, ab_range=2, epoch=880Done: four_corners, width=10, depth=1, ab_range=1, epoch=530Done: spirals, width=5, depth=8, ab_range=0.2, epoch=610
#
#
# Done: two_blobs_overlap, width=5, depth=2, ab_range=10, epoch=130Done: half_moons, width=5, depth=1, ab_range=0.1, epoch=950
# Done: spirals, width=5, depth=2, ab_range=10, epoch=720Done: two_blobs_overlap, width=5, depth=8, ab_range=0.2, epoch=50
#
#
#
#
# Done: two_blobs_separate, width=10, depth=1, ab_range=0.1, epoch=400Done: two_blobs_separate, width=5, depth=16, ab_range=0.5, epoch=180
#
# Done: half_moons, width=10, depth=1, ab_range=0.1, epoch=990Done: four_corners, width=5, depth=4, ab_range=5, epoch=460Done: two_blobs_separate, width=5, depth=1, ab_range=0.1, epoch=420
#
# Done: spirals, width=5, depth=8, ab_range=0.2, epoch=620
# Done: two_blobs_overlap, width=5, depth=2, ab_range=10, epoch=140Done: two_blobs_overlap, width=5, depth=8, ab_range=0.2, epoch=60Done: four_corners, width=5, depth=1, ab_range=1, epoch=550
#
# Done: two_blobs_separate, width=5, depth=4, ab_range=2, epoch=310Done: half_moons, width=5, depth=4, ab_range=2, epoch=890
# Done: four_corners, width=10, depth=1, ab_range=1, epoch=540Done: half_moons, width=5, depth=16, ab_range=0.5, epoch=740
# Done: half_moons, width=5, depth=1, ab_range=0.1, epoch=960Done: spirals, width=5, depth=2, ab_range=10, epoch=730
#
#
# Done: two_blobs_separate, width=5, depth=16, ab_range=0.5, epoch=190
# Done: four_corners, width=5, depth=4, ab_range=5, epoch=470
# Done: half_moons, width=10, depth=1, ab_range=0.1, epoch=1000
#
# Done: two_blobs_overlap, width=5, depth=2, ab_range=10, epoch=150
#
# Done: two_blobs_separate, width=5, depth=1, ab_range=0.1, epoch=430Done: spirals, width=5, depth=8, ab_range=0.2, epoch=630Done: four_corners, width=5, depth=1, ab_range=1, epoch=560
# Done: half_moons, width=5, depth=4, ab_range=2, epoch=900Done: four_corners, width=10, depth=1, ab_range=1, epoch=550
# Done: two_blobs_separate, width=5, depth=4, ab_range=2, epoch=320
#
#
#
#
#
#
# Done: half_moons, width=5, depth=1, ab_range=0.1, epoch=970
# Done: two_blobs_separate, width=10, depth=1, ab_range=0.1, epoch=410Done: two_blobs_overlap, width=5, depth=2, ab_range=10, epoch=160Done: four_corners, width=5, depth=4, ab_range=5, epoch=480Done: two_blobs_separate, width=5, depth=16, ab_range=0.5, epoch=200Done: half_moons, width=5, depth=16, ab_range=0.5, epoch=750Done: four_corners, width=5, depth=1, ab_range=1, epoch=570Done: half_moons, width=10, depth=1, ab_range=1, epoch=0Done: spirals, width=5, depth=2, ab_range=10, epoch=740Done: two_blobs_overlap, width=5, depth=8, ab_range=0.2, epoch=70Done: half_moons, width=5, depth=4, ab_range=2, epoch=910
#
# Done: two_blobs_separate, width=5, depth=1, ab_range=0.1, epoch=440
#
#
#
#
# Done: two_blobs_separate, width=5, depth=4, ab_range=2, epoch=330Done: spirals, width=5, depth=8, ab_range=0.2, epoch=640
# Done: half_moons, width=5, depth=1, ab_range=0.1, epoch=980
# Done: two_blobs_overlap, width=5, depth=2, ab_range=10, epoch=170Done: four_corners, width=10, depth=1, ab_range=1, epoch=560
#
#
# Done: half_moons, width=5, depth=16, ab_range=0.5, epoch=760Done: half_moons, width=10, depth=1, ab_range=1, epoch=10Done: two_blobs_separate, width=10, depth=1, ab_range=0.1, epoch=420
# Done: four_corners, width=5, depth=1, ab_range=1, epoch=580
# Done: two_blobs_separate, width=5, depth=16, ab_range=0.5, epoch=210Done: two_blobs_overlap, width=5, depth=8, ab_range=0.2, epoch=80
#
#
#
# Done: four_corners, width=5, depth=4, ab_range=5, epoch=490Done: spirals, width=5, depth=2, ab_range=10, epoch=750
# Done: two_blobs_separate, width=5, depth=4, ab_range=2, epoch=340
# Done: two_blobs_overlap, width=5, depth=2, ab_range=10, epoch=180
#
#
# Done: four_corners, width=10, depth=1, ab_range=1, epoch=570Done: half_moons, width=5, depth=4, ab_range=2, epoch=920
# Done: half_moons, width=5, depth=1, ab_range=0.1, epoch=990Done: two_blobs_separate, width=5, depth=1, ab_range=0.1, epoch=450
#
#
# Done: half_moons, width=5, depth=16, ab_range=0.5, epoch=770
# Done: half_moons, width=10, depth=1, ab_range=1, epoch=20Done: two_blobs_separate, width=5, depth=16, ab_range=0.5, epoch=220Done: four_corners, width=5, depth=1, ab_range=1, epoch=590
# Done: spirals, width=5, depth=8, ab_range=0.2, epoch=650
#
# Done: two_blobs_overlap, width=5, depth=8, ab_range=0.2, epoch=90Done: spirals, width=5, depth=2, ab_range=10, epoch=760Done: two_blobs_separate, width=10, depth=1, ab_range=0.1, epoch=430Done: four_corners, width=5, depth=4, ab_range=5, epoch=500Done: two_blobs_separate, width=5, depth=4, ab_range=2, epoch=350
# Done: two_blobs_overlap, width=5, depth=2, ab_range=10, epoch=190
#
#
#
# Done: half_moons, width=5, depth=1, ab_range=0.1, epoch=1000Done: half_moons, width=5, depth=4, ab_range=2, epoch=930Done: four_corners, width=10, depth=1, ab_range=1, epoch=580
#
#
#
#
# Done: two_blobs_separate, width=5, depth=1, ab_range=0.1, epoch=460
# Done: spirals, width=5, depth=8, ab_range=0.2, epoch=660Done: half_moons, width=5, depth=16, ab_range=0.5, epoch=780Done: half_moons, width=10, depth=1, ab_range=1, epoch=30Done: four_corners, width=5, depth=1, ab_range=1, epoch=600
#
#
# Done: two_blobs_separate, width=5, depth=16, ab_range=0.5, epoch=230Done: spirals, width=5, depth=2, ab_range=10, epoch=770
#
#
# Done: two_blobs_overlap, width=5, depth=2, ab_range=10, epoch=200Done: two_blobs_separate, width=5, depth=4, ab_range=2, epoch=360Done: half_moons, width=5, depth=1, ab_range=1, epoch=0Done: four_corners, width=5, depth=4, ab_range=5, epoch=510
#
# Done: half_moons, width=5, depth=4, ab_range=2, epoch=940
#
# Done: spirals, width=5, depth=8, ab_range=0.2, epoch=670
# Done: four_corners, width=10, depth=1, ab_range=1, epoch=590
#
# Done: two_blobs_separate, width=10, depth=1, ab_range=0.1, epoch=440Done: four_corners, width=5, depth=1, ab_range=1, epoch=610Done: two_blobs_separate, width=5, depth=16, ab_range=0.5, epoch=240
#
#
# Done: spirals, width=5, depth=2, ab_range=10, epoch=780Done: half_moons, width=5, depth=16, ab_range=0.5, epoch=790
# Done: half_moons, width=10, depth=1, ab_range=1, epoch=40Done: two_blobs_overlap, width=5, depth=2, ab_range=10, epoch=210
#
# Done: two_blobs_separate, width=5, depth=4, ab_range=2, epoch=370
#
# Done: half_moons, width=5, depth=1, ab_range=1, epoch=10Done: four_corners, width=5, depth=4, ab_range=5, epoch=520
# Done: spirals, width=5, depth=8, ab_range=0.2, epoch=680Done: four_corners, width=10, depth=1, ab_range=1, epoch=600
#
# Done: four_corners, width=5, depth=1, ab_range=1, epoch=620Done: two_blobs_overlap, width=5, depth=8, ab_range=0.2, epoch=100
#
# Done: two_blobs_separate, width=5, depth=16, ab_range=0.5, epoch=250Done: two_blobs_separate, width=10, depth=1, ab_range=0.1, epoch=450
#
#
# Done: half_moons, width=5, depth=16, ab_range=0.5, epoch=800Done: half_moons, width=10, depth=1, ab_range=1, epoch=50Done: two_blobs_overlap, width=5, depth=2, ab_range=10, epoch=220
#
# Done: four_corners, width=5, depth=4, ab_range=5, epoch=530
#
#
# Done: four_corners, width=10, depth=1, ab_range=1, epoch=610Done: half_moons, width=5, depth=1, ab_range=1, epoch=20
# Done: two_blobs_separate, width=5, depth=4, ab_range=2, epoch=380
#
#
# Done: spirals, width=5, depth=8, ab_range=0.2, epoch=690Done: two_blobs_separate, width=5, depth=1, ab_range=0.1, epoch=470Done: two_blobs_overlap, width=5, depth=8, ab_range=0.2, epoch=110
