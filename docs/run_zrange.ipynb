# %%
import numpy as np
import multiprocessing as mp
from itertools import product


from visualize_landscape import *


torch.set_num_threads(1)

# %%
def worker(args):
    dataset, width, depth, ab_range, epoch, gridsize = args
    arch = [width] * depth

    try:
        #print(f"Processing: epoch={epoch}, ab_range={ab_range}, width={width}, depth={depth}, dataset={dataset}")
    

        compute_and_save_zrange(  arch=arch, dataset=dataset,  train=True,  ab_range=ab_range, gridsize=gridsize)
        print(f"Done: {dataset}, width={width}, depth={depth}, ab_range={ab_range}, epoch={epoch}")

    except Exception as e:
        print(f"Failed: {dataset}, width={width}, depth={depth}, ab_range={ab_range}, epoch={epoch}. Reason: {e}")
        


num_epochs = 1001
datasets = ["two_blobs_separate", "two_blobs_overlap", "half_moons", "spirals", "four_corners"]
widths = [5,10,25,50,100]  # optionally extend
depths = [1,2,4,8,16]   # optionally extend
ab_ranges = [0.1, 1, 10,2,5,.2,.5]
epochs = list(range(0, num_epochs, 10))
gridsize = 100

# Prepare the argument list for all jobs
all_args = list(product( widths, depths,datasets, ab_ranges, epochs))


all_args = [ (dataset,  width, depth, ab_range, epoch, gridsize) for ( width, depth, dataset,ab_range, epoch) in all_args]


for args in all_args:
    worker(args)
# Out:
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range0.1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=0.1, epoch=430
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range0.1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=0.1, epoch=440
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range0.1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=0.1, epoch=450
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range0.1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=0.1, epoch=460
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range0.1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=0.1, epoch=470
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range0.1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=0.1, epoch=480
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range0.1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=0.1, epoch=490
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range0.1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=0.1, epoch=500
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range0.1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=0.1, epoch=510
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range0.1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=0.1, epoch=520
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range0.1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=0.1, epoch=530
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range0.1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=0.1, epoch=540
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range0.1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=0.1, epoch=550
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range0.1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=0.1, epoch=560
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range0.1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=0.1, epoch=570
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range0.1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=0.1, epoch=580
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range0.1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=0.1, epoch=590
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range0.1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=0.1, epoch=600
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range0.1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=0.1, epoch=610
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range0.1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=0.1, epoch=620
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range0.1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=0.1, epoch=630
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range0.1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=0.1, epoch=640
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range0.1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=0.1, epoch=650
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range0.1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=0.1, epoch=660
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range0.1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=0.1, epoch=670
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range0.1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=0.1, epoch=680
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range0.1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=0.1, epoch=690
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range0.1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=0.1, epoch=700
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range0.1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=0.1, epoch=710
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range0.1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=0.1, epoch=720
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range0.1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=0.1, epoch=730
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range0.1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=0.1, epoch=740
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range0.1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=0.1, epoch=750
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range0.1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=0.1, epoch=760
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range0.1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=0.1, epoch=770
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range0.1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=0.1, epoch=780
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range0.1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=0.1, epoch=790
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range0.1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=0.1, epoch=800
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range0.1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=0.1, epoch=810
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range0.1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=0.1, epoch=820
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range0.1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=0.1, epoch=830
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range0.1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=0.1, epoch=840
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range0.1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=0.1, epoch=850
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range0.1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=0.1, epoch=860
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range0.1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=0.1, epoch=870
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range0.1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=0.1, epoch=880
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range0.1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=0.1, epoch=890
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range0.1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=0.1, epoch=900
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range0.1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=0.1, epoch=910
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range0.1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=0.1, epoch=920
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range0.1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=0.1, epoch=930
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range0.1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=0.1, epoch=940
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range0.1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=0.1, epoch=950
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range0.1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=0.1, epoch=960
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range0.1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=0.1, epoch=970
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range0.1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=0.1, epoch=980
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range0.1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=0.1, epoch=990
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range0.1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=0.1, epoch=1000
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=0
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=10
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=20
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=30
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=40
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=50
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=60
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=70
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=80
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=90
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=100
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=110
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=120
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=130
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=140
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=150
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=160
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=170
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=180
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=190
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=200
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=210
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=220
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=230
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=240
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=250
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=260
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=270
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=280
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=290
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=300
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=310
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=320
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=330
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=340
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=350
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=360
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=370
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=380
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=390
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=400
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=410
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=420
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=430
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=440
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=450
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=460
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=470
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=480
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=490
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=500
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=510
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=520
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=530
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=540
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=550
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=560
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=570
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=580
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=590
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=600
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=610
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=620
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=630
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=640
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=650
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=660
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=670
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=680
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=690
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=700
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=710
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=720
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=730
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=740
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=750
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=760
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=770
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=780
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=790
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=800
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=810
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=820
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=830
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=840
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=850
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=860
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=870
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=880
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=890
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=900
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=910
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=920
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=930
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=940
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=950
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=960
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=970
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=980
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=990
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range1/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=1, epoch=1000
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=10, epoch=0
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=10, epoch=10
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=10, epoch=20
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=10, epoch=30
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=10, epoch=40
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=10, epoch=50
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=10, epoch=60
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=10, epoch=70
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=10, epoch=80
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=10, epoch=90
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=10, epoch=100
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=10, epoch=110
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=10, epoch=120
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=10, epoch=130
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=10, epoch=140
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=10, epoch=150
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=10, epoch=160
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=10, epoch=170
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=10, epoch=180
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=10, epoch=190
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=10, epoch=200
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=10, epoch=210
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=10, epoch=220
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=10, epoch=230
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=10, epoch=240
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=10, epoch=250
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=10, epoch=260
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=10, epoch=270
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=10, epoch=280
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=10, epoch=290
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=10, epoch=300
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=10, epoch=310
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=10, epoch=320
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=10, epoch=330
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=10, epoch=340
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=10, epoch=350
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=10, epoch=360
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=10, epoch=370
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=10, epoch=380
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=10, epoch=390
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=10, epoch=400
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=10, epoch=410
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=10, epoch=420
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=10, epoch=430
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=10, epoch=440
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=10, epoch=450
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=10, epoch=460
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=10, epoch=470
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=10, epoch=480
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=10, epoch=490
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=10, epoch=500
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=10, epoch=510
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=10, epoch=520
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=10, epoch=530
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=10, epoch=540
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=10, epoch=550
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=10, epoch=560
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=10, epoch=570
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=10, epoch=580
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=10, epoch=590
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=10, epoch=600
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=10, epoch=610
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=10, epoch=620
# ✅ zrange already computed at ../backend/landscapes/mlp_25_25_25_25_25_25_25_25/two_blobs_separate/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_separate, width=25, depth=8, ab_range=10, epoch=630
# ...
# Done: two_blobs_overlap, width=50, depth=2, ab_range=10, epoch=200
# ✅ zrange already computed at ../backend/landscapes/mlp_50_50/two_blobs_overlap/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_overlap, width=50, depth=2, ab_range=10, epoch=210
# ✅ zrange already computed at ../backend/landscapes/mlp_50_50/two_blobs_overlap/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_overlap, width=50, depth=2, ab_range=10, epoch=220
# ✅ zrange already computed at ../backend/landscapes/mlp_50_50/two_blobs_overlap/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_overlap, width=50, depth=2, ab_range=10, epoch=230
# ✅ zrange already computed at ../backend/landscapes/mlp_50_50/two_blobs_overlap/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_overlap, width=50, depth=2, ab_range=10, epoch=240
# ✅ zrange already computed at ../backend/landscapes/mlp_50_50/two_blobs_overlap/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_overlap, width=50, depth=2, ab_range=10, epoch=250
# ✅ zrange already computed at ../backend/landscapes/mlp_50_50/two_blobs_overlap/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_overlap, width=50, depth=2, ab_range=10, epoch=260
# ✅ zrange already computed at ../backend/landscapes/mlp_50_50/two_blobs_overlap/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_overlap, width=50, depth=2, ab_range=10, epoch=270
# ✅ zrange already computed at ../backend/landscapes/mlp_50_50/two_blobs_overlap/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_overlap, width=50, depth=2, ab_range=10, epoch=280
# ✅ zrange already computed at ../backend/landscapes/mlp_50_50/two_blobs_overlap/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_overlap, width=50, depth=2, ab_range=10, epoch=290
# ✅ zrange already computed at ../backend/landscapes/mlp_50_50/two_blobs_overlap/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_overlap, width=50, depth=2, ab_range=10, epoch=300
# ✅ zrange already computed at ../backend/landscapes/mlp_50_50/two_blobs_overlap/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_overlap, width=50, depth=2, ab_range=10, epoch=310
# ✅ zrange already computed at ../backend/landscapes/mlp_50_50/two_blobs_overlap/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_overlap, width=50, depth=2, ab_range=10, epoch=320
# ✅ zrange already computed at ../backend/landscapes/mlp_50_50/two_blobs_overlap/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_overlap, width=50, depth=2, ab_range=10, epoch=330
# ✅ zrange already computed at ../backend/landscapes/mlp_50_50/two_blobs_overlap/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_overlap, width=50, depth=2, ab_range=10, epoch=340
# ✅ zrange already computed at ../backend/landscapes/mlp_50_50/two_blobs_overlap/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_overlap, width=50, depth=2, ab_range=10, epoch=350
# ✅ zrange already computed at ../backend/landscapes/mlp_50_50/two_blobs_overlap/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_overlap, width=50, depth=2, ab_range=10, epoch=360
# ✅ zrange already computed at ../backend/landscapes/mlp_50_50/two_blobs_overlap/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_overlap, width=50, depth=2, ab_range=10, epoch=370
# ✅ zrange already computed at ../backend/landscapes/mlp_50_50/two_blobs_overlap/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_overlap, width=50, depth=2, ab_range=10, epoch=380
# ✅ zrange already computed at ../backend/landscapes/mlp_50_50/two_blobs_overlap/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_overlap, width=50, depth=2, ab_range=10, epoch=390
# ✅ zrange already computed at ../backend/landscapes/mlp_50_50/two_blobs_overlap/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_overlap, width=50, depth=2, ab_range=10, epoch=400
# ✅ zrange already computed at ../backend/landscapes/mlp_50_50/two_blobs_overlap/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_overlap, width=50, depth=2, ab_range=10, epoch=410
# ✅ zrange already computed at ../backend/landscapes/mlp_50_50/two_blobs_overlap/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_overlap, width=50, depth=2, ab_range=10, epoch=420
# ✅ zrange already computed at ../backend/landscapes/mlp_50_50/two_blobs_overlap/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_overlap, width=50, depth=2, ab_range=10, epoch=430
# ✅ zrange already computed at ../backend/landscapes/mlp_50_50/two_blobs_overlap/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_overlap, width=50, depth=2, ab_range=10, epoch=440
# ✅ zrange already computed at ../backend/landscapes/mlp_50_50/two_blobs_overlap/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_overlap, width=50, depth=2, ab_range=10, epoch=450
# ✅ zrange already computed at ../backend/landscapes/mlp_50_50/two_blobs_overlap/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_overlap, width=50, depth=2, ab_range=10, epoch=460
# ✅ zrange already computed at ../backend/landscapes/mlp_50_50/two_blobs_overlap/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_overlap, width=50, depth=2, ab_range=10, epoch=470
# ✅ zrange already computed at ../backend/landscapes/mlp_50_50/two_blobs_overlap/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_overlap, width=50, depth=2, ab_range=10, epoch=480
# ✅ zrange already computed at ../backend/landscapes/mlp_50_50/two_blobs_overlap/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_overlap, width=50, depth=2, ab_range=10, epoch=490
# ✅ zrange already computed at ../backend/landscapes/mlp_50_50/two_blobs_overlap/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_overlap, width=50, depth=2, ab_range=10, epoch=500
# ✅ zrange already computed at ../backend/landscapes/mlp_50_50/two_blobs_overlap/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_overlap, width=50, depth=2, ab_range=10, epoch=510
# ✅ zrange already computed at ../backend/landscapes/mlp_50_50/two_blobs_overlap/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_overlap, width=50, depth=2, ab_range=10, epoch=520
# ✅ zrange already computed at ../backend/landscapes/mlp_50_50/two_blobs_overlap/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_overlap, width=50, depth=2, ab_range=10, epoch=530
# ✅ zrange already computed at ../backend/landscapes/mlp_50_50/two_blobs_overlap/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_overlap, width=50, depth=2, ab_range=10, epoch=540
# ✅ zrange already computed at ../backend/landscapes/mlp_50_50/two_blobs_overlap/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_overlap, width=50, depth=2, ab_range=10, epoch=550
# ✅ zrange already computed at ../backend/landscapes/mlp_50_50/two_blobs_overlap/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_overlap, width=50, depth=2, ab_range=10, epoch=560
# ✅ zrange already computed at ../backend/landscapes/mlp_50_50/two_blobs_overlap/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_overlap, width=50, depth=2, ab_range=10, epoch=570
# ✅ zrange already computed at ../backend/landscapes/mlp_50_50/two_blobs_overlap/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_overlap, width=50, depth=2, ab_range=10, epoch=580
# ✅ zrange already computed at ../backend/landscapes/mlp_50_50/two_blobs_overlap/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_overlap, width=50, depth=2, ab_range=10, epoch=590
# ✅ zrange already computed at ../backend/landscapes/mlp_50_50/two_blobs_overlap/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_overlap, width=50, depth=2, ab_range=10, epoch=600
# ✅ zrange already computed at ../backend/landscapes/mlp_50_50/two_blobs_overlap/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_overlap, width=50, depth=2, ab_range=10, epoch=610
# ✅ zrange already computed at ../backend/landscapes/mlp_50_50/two_blobs_overlap/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_overlap, width=50, depth=2, ab_range=10, epoch=620
# ✅ zrange already computed at ../backend/landscapes/mlp_50_50/two_blobs_overlap/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_overlap, width=50, depth=2, ab_range=10, epoch=630
# ✅ zrange already computed at ../backend/landscapes/mlp_50_50/two_blobs_overlap/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_overlap, width=50, depth=2, ab_range=10, epoch=640
# ✅ zrange already computed at ../backend/landscapes/mlp_50_50/two_blobs_overlap/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_overlap, width=50, depth=2, ab_range=10, epoch=650
# ✅ zrange already computed at ../backend/landscapes/mlp_50_50/two_blobs_overlap/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_overlap, width=50, depth=2, ab_range=10, epoch=660
# ✅ zrange already computed at ../backend/landscapes/mlp_50_50/two_blobs_overlap/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_overlap, width=50, depth=2, ab_range=10, epoch=670
# ✅ zrange already computed at ../backend/landscapes/mlp_50_50/two_blobs_overlap/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_overlap, width=50, depth=2, ab_range=10, epoch=680
# ✅ zrange already computed at ../backend/landscapes/mlp_50_50/two_blobs_overlap/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_overlap, width=50, depth=2, ab_range=10, epoch=690
# ✅ zrange already computed at ../backend/landscapes/mlp_50_50/two_blobs_overlap/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_overlap, width=50, depth=2, ab_range=10, epoch=700
# ✅ zrange already computed at ../backend/landscapes/mlp_50_50/two_blobs_overlap/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_overlap, width=50, depth=2, ab_range=10, epoch=710
# ✅ zrange already computed at ../backend/landscapes/mlp_50_50/two_blobs_overlap/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_overlap, width=50, depth=2, ab_range=10, epoch=720
# ✅ zrange already computed at ../backend/landscapes/mlp_50_50/two_blobs_overlap/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_overlap, width=50, depth=2, ab_range=10, epoch=730
# ✅ zrange already computed at ../backend/landscapes/mlp_50_50/two_blobs_overlap/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_overlap, width=50, depth=2, ab_range=10, epoch=740
# ✅ zrange already computed at ../backend/landscapes/mlp_50_50/two_blobs_overlap/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_overlap, width=50, depth=2, ab_range=10, epoch=750
# ✅ zrange already computed at ../backend/landscapes/mlp_50_50/two_blobs_overlap/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_overlap, width=50, depth=2, ab_range=10, epoch=760
# ✅ zrange already computed at ../backend/landscapes/mlp_50_50/two_blobs_overlap/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_overlap, width=50, depth=2, ab_range=10, epoch=770
# ✅ zrange already computed at ../backend/landscapes/mlp_50_50/two_blobs_overlap/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_overlap, width=50, depth=2, ab_range=10, epoch=780
# ✅ zrange already computed at ../backend/landscapes/mlp_50_50/two_blobs_overlap/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_overlap, width=50, depth=2, ab_range=10, epoch=790
# ✅ zrange already computed at ../backend/landscapes/mlp_50_50/two_blobs_overlap/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_overlap, width=50, depth=2, ab_range=10, epoch=800
# ✅ zrange already computed at ../backend/landscapes/mlp_50_50/two_blobs_overlap/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_overlap, width=50, depth=2, ab_range=10, epoch=810
# ✅ zrange already computed at ../backend/landscapes/mlp_50_50/two_blobs_overlap/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_overlap, width=50, depth=2, ab_range=10, epoch=820
# ✅ zrange already computed at ../backend/landscapes/mlp_50_50/two_blobs_overlap/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_overlap, width=50, depth=2, ab_range=10, epoch=830
# ✅ zrange already computed at ../backend/landscapes/mlp_50_50/two_blobs_overlap/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_overlap, width=50, depth=2, ab_range=10, epoch=840
# ✅ zrange already computed at ../backend/landscapes/mlp_50_50/two_blobs_overlap/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_overlap, width=50, depth=2, ab_range=10, epoch=850
# ✅ zrange already computed at ../backend/landscapes/mlp_50_50/two_blobs_overlap/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_overlap, width=50, depth=2, ab_range=10, epoch=860
# ✅ zrange already computed at ../backend/landscapes/mlp_50_50/two_blobs_overlap/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_overlap, width=50, depth=2, ab_range=10, epoch=870
# ✅ zrange already computed at ../backend/landscapes/mlp_50_50/two_blobs_overlap/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_overlap, width=50, depth=2, ab_range=10, epoch=880
# ✅ zrange already computed at ../backend/landscapes/mlp_50_50/two_blobs_overlap/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_overlap, width=50, depth=2, ab_range=10, epoch=890
# ✅ zrange already computed at ../backend/landscapes/mlp_50_50/two_blobs_overlap/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_overlap, width=50, depth=2, ab_range=10, epoch=900
# ✅ zrange already computed at ../backend/landscapes/mlp_50_50/two_blobs_overlap/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_overlap, width=50, depth=2, ab_range=10, epoch=910
# ✅ zrange already computed at ../backend/landscapes/mlp_50_50/two_blobs_overlap/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_overlap, width=50, depth=2, ab_range=10, epoch=920
# ✅ zrange already computed at ../backend/landscapes/mlp_50_50/two_blobs_overlap/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_overlap, width=50, depth=2, ab_range=10, epoch=930
# ✅ zrange already computed at ../backend/landscapes/mlp_50_50/two_blobs_overlap/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_overlap, width=50, depth=2, ab_range=10, epoch=940
# ✅ zrange already computed at ../backend/landscapes/mlp_50_50/two_blobs_overlap/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_overlap, width=50, depth=2, ab_range=10, epoch=950
# ✅ zrange already computed at ../backend/landscapes/mlp_50_50/two_blobs_overlap/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_overlap, width=50, depth=2, ab_range=10, epoch=960
# ✅ zrange already computed at ../backend/landscapes/mlp_50_50/two_blobs_overlap/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_overlap, width=50, depth=2, ab_range=10, epoch=970
# ✅ zrange already computed at ../backend/landscapes/mlp_50_50/two_blobs_overlap/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_overlap, width=50, depth=2, ab_range=10, epoch=980
# ✅ zrange already computed at ../backend/landscapes/mlp_50_50/two_blobs_overlap/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_overlap, width=50, depth=2, ab_range=10, epoch=990
# ✅ zrange already computed at ../backend/landscapes/mlp_50_50/two_blobs_overlap/train/range10/zrange.npy. Skipping computation.
# Done: two_blobs_overlap, width=50, depth=2, ab_range=10, epoch=1000
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
